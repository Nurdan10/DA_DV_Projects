# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# <p style="background-color:romance; color:plum; font-size:150%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1; font-weight:bold;">WAY TO REINVENT YOURSELF</p>
#
# <p style="background-color:romance; color:jaguar; font-size:250%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;"><strong>Data Analysis & Visualization with Python</strong></p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# <p style="background-color:romance; color:jaguar; font-size:200%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;"><strong>Analysis of US Citizens by Income Levels</strong></p>
#
# <!-- <p style="background-color:romance; color:jaguar; font-size:200%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.1;">Project Solution</p> -->

# %% [markdown]
# <a id="content"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Content</p>
#
# * [Introduction](#0)
# * [About Dataset](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# <a id="0"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Introduction</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is **good practice to understand the problem statement** and the data before you get your hands dirty, which in view, **helps to gain a lot of insights**. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# **Aim of the Project**
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# <a id="1"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">About Dataset</p>
#
# <a href="https://www.kaggle.com/code/jieyima/income-classification-model/notebook" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Kaggle: Income Classification Model</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# **Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)**
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# **Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)**
#
#
# **Installing hinterland for jupyter without anaconda**
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# <a id="2"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Importing Related Libraries</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# - Once you've Installed NumPy and Pandas etc. you can Import them as a Library.
# - Reading the Data from File

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Statistics functions
from scipy import stats

import warnings
# Suppressing a warning 
warnings.filterwarnings("ignore") 
warnings.warn("this will not show")

# The style parameters control properties like the color of the background and whether a grid is enabled by default.

sns.set_style("whitegrid")

params = {
'figure.figsize':(12,5),
'figure.titlesize':20,
'font.size': 15,
'axes.titlesize': 20,
'axes.labelsize': 15,
'xtick.labelsize': 15,
'ytick.labelsize': 15,
'legend.fontsize': 15,
'boxplot.showmeans': True,
'boxplot.meanprops.marker': 'o',
'boxplot.meanprops.markeredgecolor': 'k',
'boxplot.meanprops.markerfacecolor': 'w',
'boxplot.meanprops.markersize': 10.1,

   
}
# print(plt.style.library)
plt.rcParams.update(params)
# plt.rcParams.update(plt.rcParamsDefault)
# print(plt.rcParams['figure.figsize'])

# Environment settings: 
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# Set it None to display all rows in the dataframe
pd.set_option('display.max_rows', 100)
# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# It is a magic function that renders the figure in the notebook
# Attention if U use this inline Command not work 'figure.figsize'
# %matplotlib inline

# %%
sns.set(font_scale=0.8)

# %% [markdown]
# ## Reading the Data from File

# %% [markdown]
# <a id="3"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Recognizing and Understanding Data</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - Basically check the missing values. (NaN, None)
# - If needed, rename the columns' names for easy use.

# %% [markdown]
# ### Check the head, shape, data-types of the features.

# %%
# Your Code is Here

df = pd.read_csv('adult_eda.csv')

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/qFn8RZs/US-Citicens1.png)

# %%
# Your Code is Here
df.shape
# Out:
# (32561, 15)

# %% [raw]
# Desired Output:
#
# (32561, 15)

# %%
# Your Code is Here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %% [raw]
# Desired Output:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ### Check if there are some dublicate rows or not. If there are, then drop them.

# %%
# Check if the Dataset have any Duplicate

# Your Code is Here
df.duplicated().value_counts()
# Out:
# False    32537
# True        24
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# False    32537
# True        24
# dtype: int64

# %%
# Drop Duplicates

# Your Code is Here
df.drop_duplicates(inplace=True)

# %%
# Check the shape of the Dataset

# Your Code is Here

df.shape
# Out:
# (32537, 15)

# %% [raw]
# Desired Output:
#
# (32537, 15)

# %% [markdown]
# ### Check the statistical values of features.

# %%
# Your Code is Here
df.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32537.000     38.586     13.638    17.000     28.000
# fnlwgt         32537.000 189780.849 105556.471 12285.000 117827.000
# education-num  31735.000     10.084      2.575     1.000      9.000
# capital-gain   32537.000   1078.444   7387.957     0.000      0.000
# capital-loss   32537.000     87.368    403.102     0.000      0.000
# hours-per-week 32537.000     40.440     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 236993.000 1484705.000
# education-num      10.000     12.000      16.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/HnG6Xdn/US-Citicens2.png)

# %% [markdown]
# ### Basically check the missing values. (NaN, None)

# %%
# Check the sum of Missing Values per column
# Your Code is Here
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5064
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [raw]
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# gender               0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %%
# Check the Percentage of Missing Values
# Your Code is Here

df.isnull().sum() / len(df) * 100
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education-num     2.465
# marital-status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# sex               0.000
# capital-gain      0.000
# capital-loss      0.000
# hours-per-week    0.000
# native-country    0.000
# salary            0.000
# dtype: float64

# %% [raw]
# Desired Output:
#
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education_num     2.465
# marital_status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# gender            0.000
# capital_gain      0.000
# capital_loss      0.000
# hours_per_week    0.000
# native_country    0.000
# salary            0.000
# dtype: float64

# %% [markdown]
# ### If needed, rename the columns' names for easy use.

# %% [markdown]
# **Rename the features of;**<br>
# **``"education-num"``**, **``"marital-status"``**, **``"capital-gain"``**, **``"capital-loss"``**, **``"hours-per-week"``**, **``"native-country"``** **as**<br>
# **``"education_num"``**, **``"marital_status"``**, **``"capital_gain"``**, **``"capital_loss"``**, **``"hours_per_week"``**, **``"native_country"``**, **respectively and permanently.**

# %%
# Your Code is Here
new_column_names = {"education-num":"education_num", 
                    "marital-status":"marital_status",
                    "capital-gain":"capital_gain", 
                    "capital-loss":"capital_loss",
                    "hours-per-week":"hours_per_week",
                    "native-country":"native_country"}
df.rename(columns = new_column_names, inplace=True)

# %% [markdown]
# ## Examining the Data
# - Look at the counts of columns that have OBJECT datatype
# - Assign the Columns (Features) of object data type as** **`"object_col"`**
# - Detect strange values apart from the NaN Values.(isin(),Count(),Sum(),Any())

# %% [markdown]
# ### Look at the value counts of columns that have OBJECT datatype

# %%
# Your Code is Here
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %% [raw]
# Desired Output:
#
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'gender',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
# Your Code is Here

df[df.columns[df.dtypes == 'object']].describe().T
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# sex             32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/WspBGfZ/US-Citicens3.png)

# %% [markdown]
# ### Assign the Columns (Features) of object data type as** **``"object_col"``

# %%
# Your Code is Here
object_col = df.columns[df.dtypes == 'object']
object_col
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'salary'],
#       dtype='object')

# %% [raw]
# Desired Output:
#
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'gender', 'native_country', 'salary'],
#       dtype='object')

# %%
for col in object_col:
    print(col)
    print("**"*20)
    print(df[col].value_counts(dropna=False))
    print("--"*20)
# Out:
# workclass
# ****************************************
# workclass
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64
# ----------------------------------------
# education
# ****************************************
# education
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: count, dtype: int64
# ----------------------------------------
# marital_status
# ****************************************
# marital_status
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: count, dtype: int64
# ----------------------------------------
# occupation
# ****************************************
# occupation
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: count, dtype: int64
# ----------------------------------------
# relationship
# ****************************************
# relationship
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: count, dtype: int64
# ----------------------------------------
# race
# ****************************************
# race
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64
# ----------------------------------------
# sex
# ****************************************
# sex
# Male      21775
# Female    10762
# Name: count, dtype: int64
# ----------------------------------------
# native_country
# ****************************************
# native_country
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: count, dtype: int64
# ----------------------------------------
# salary
# ****************************************
# salary
# <=50K    24698
# >50K      7839
# Name: count, dtype: int64
# ----------------------------------------

# %% [markdown]
# ### Detect strange values apart from the NaN Values.(isin(),Count(),Sum(),Any())

# %% [markdown]
# **Check if the Dataset has any Question Mark** **``"?"``**

# %%
# Your Code is Here

df.isin(['?']).any()
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [raw]
# Desired Output:
#
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# gender            False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [markdown]
# <a id="4"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Univariate & Multivariate Analysis</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all Features:
# - **Target Feature**
# - **Numeric Ones**
# - **Categoric Ones** separately from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by target feature
# 5. Check the statistical values by target feature
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count/percentage in each target feature by categories and visualize it with a suitable plot
# 5. Check the percentage distribution in each target feature by categories and visualize it with suitable plot
# 6. Check the count in each categories by target feature and visualize it with a suitable plot
# 7. Check the percentage distribution in each categories by target feature and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** **Instruction/direction** for each feature is available under the corresponding feature in detail, as well.

# %% [markdown]
# ## Target Feature
# - Salary

# %% [markdown]
# **Check the count of person in each "salary" levels and visualize it with a countplot**

# %%
sns.set(font_scale=0.8)
plt.figure(figsize=(9,5))
ax = sns.countplot(x='salary', lw=(0,5), data=df, palette='tab10')
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0,5), 
                textcoords = 'offset points')

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/9qwrtB1/US-Citicens4.png)

# %%
# Your Code is Here
df.salary.value_counts()
# Out:
# salary
# <=50K    24698
# >50K      7839
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %% [markdown]
# **Check the percentage of person in each "salary" levels and visualize it with a pieplot**

# %%
# Your Code is Here

salary_percentage = df.salary.value_counts(normalize=True)
salary_percentage
# Out:
# salary
# <=50K   0.759
# >50K    0.241
# Name: proportion, dtype: float64

# %%
# Your Code is Here
plt.figure(figsize=(7,5))
colors='#87CEFA', '#FFE45B'
myexplode = (0.1, 0)
plt.title('Percentage of Income-Levels', fontsize=15)
plt.pie(salary_percentage, colors=colors, labels=salary_percentage.index, shadow = True, autopct='%1.1f%%', explode=myexplode, startangle=360)
plt.tight_layout()
plt.show()

# %% [raw]
# Desired Output:
#
# <=50K   0.759
# >50K    0.241
# Name: salary, dtype: float64

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/8YFvBrq/US-Citices5.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Approximately one-third of US citizens in our data earn over $50,000, with a rate of 24.1%.

# %% [markdown]
# ## Numeric Features

# %% [markdown]
# ### age

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here
sns.set_style('whitegrid')
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='age', palette='tab10', showmeans=False,);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/JKKwy5K/US-Citizens6.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here
plt.figure(figsize=(8, 5))

sns.histplot(data=df, x='age', kde=True, alpha=0.5, bins=20, palette='tab10')
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/JcJ9cyp/US-Citizens7.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here
df['age'].describe()
# Out:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [raw]
# Desired Output:
#
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here
plt.figure(figsize=(8, 6))
sns.boxplot(x='salary', y='age', data=df, showmeans=False, palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/64tBVNT/US-Citizens8.png)

# %%
# Your Code is Here
plt.figure(figsize=(8, 5))
sns.histplot( data=df, x='age', kde=True, hue='salary', bins=20, palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/q5P0sVf/US-Citizens9.png)

# %%
# Your Code is Here
plt.figure(figsize=(8, 5))
sns.kdeplot(x='age', data=df, legend=True, hue='salary', fill=True, palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/7Y2HkxB/US-Citizens10.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here
df.groupby('salary')['age'].describe()
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/xYYZcZZ/US-Citizens11.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** From the statistical summary of age grouped by salary levels:
#
# Individuals with higher salaries tend to be older on average compared to those with lower salaries.
#
# The distribution of ages among individuals earning more than 50.000 dolars has a smaller standard deviation, indicating less variability compared to those earning less than or equal to 50.000 dolars.
#
# The median age for individuals earning more than 50.000 dolars is higher, indicating a tendency towards older ages within this group.
#
# The minimum age for individuals earning more than 50.000 dolars is slightly higher than for those earning less than or equal to 50.000 dolars, indicating that higher salaries may generally require more experience or qualifications.
#
# The maximum age is the same for both salary groups, suggesting that there may be a limit on the age of individuals in the dataset, possibly due to retirement or oth.r factors. factors.rs.rs.ors.
# ors.
# ors.
# ors.factors.tors.

# %% [markdown]
# ### fnlwgt

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here
plt.figure(figsize=(8, 6))
sns.boxplot(x='fnlwgt', data=df, showmeans=False, palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/x2TtkzH/US-Citizens12.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here
plt.figure(figsize=(6, 4))
sns.kdeplot(x='fnlwgt', data=df, fill=True, palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/ZmMV8nv/US-Citizens13.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df['fnlwgt'].describe()
# Out:
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %% [raw]
# Desired Output:
#
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here
plt.figure(figsize=(8, 6))
sns.boxplot(x='salary', y='fnlwgt', data=df, showmeans=False);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/ZxJS7JW/US-Citizens14.png)

# %%
# Your Code is Here
plt.figure(figsize=(6,4))
sns.kdeplot(x='fnlwgt', data=df, legend=True, hue='salary', fill=True, palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/TgygLrz/US-Citizens15.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby('salary')['fnlwgt'].describe()
# Out:
#            count       mean        std       min        25%        50%  \
# salary
# <=50K  24698.000 190345.927 106487.413 12285.000 117606.000 179465.000
# >50K    7839.000 188000.481 102554.464 14878.000 119100.000 176063.000
#
#               75%         max
# salary
# <=50K  238968.250 1484705.000
# >50K   230969.000 1226583.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/LzWqdBf/US-Citizens16.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** The provided statistical values contain the statistical summary of the "fnlwgt" column grouped by the "salary" categories.  Here are some conclusions that can be drawn based on these statistics:
#
# Count: There are 24.698 individuals earning less than or equal to 50.000 dolars and 7.839 individuals earning more than 50.000 dolars. This indicates that individuals with lower salaries are represented in larger numbers.
#
# Mean: The average number of people represented by entries for individuals earning less than or equal to 50.000 dolars is approximately 190.346, while for individuals earning more than 50.000 dolars, it is approximately 188.000. This suggests that both salary groups have a similar average number of represented individuals.
#
# Standard Deviation: The standard deviation of the number of people represented by entries for individuals earning less than or equal to 50.000 dolars is approximately 106.487, whereas for individuals earning more than 50.000 dolars, it is approximately 102.554. This indicates that there is a similar spread in the number of represented individuals between the two groups.
#
# Minimum and Maximum: The minimum number of represented individuals for those earning less than or equal to 50.000 dolars is 12.285, and the maximum is 1.484.705. For those earning more than 50.000 dolars, the minimum is 14.878, and the maximum is 1.226.583. This shows that both salary groups have different ranges of represented individuals, but both groups have a wide range.
#
# These results suggest that the "fnlwgt" attribute (number of people represented by the census entry) is not evenly distributed across salary categories. Individuals with lower salaries are represented in larger numbers and have greater diversity.diversity.

# %% [markdown]
# ### capital_gain

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
df.sample(5)
# Out:
#        age workclass  fnlwgt     education  education_num      marital_status  \
# 11294   73         ?   89852       1st-4th          2.000  Married-civ-spouse
# 22183   59   Private  158776           9th          5.000  Married-civ-spouse
# 9686    51   Private   98791  Some-college         10.000  Married-civ-spouse
# 19164   42   Private  332401     Bachelors         13.000       Never-married
# 113     28   Private  377869  Some-college         10.000  Married-civ-spouse
#
#               occupation   relationship   race     sex  capital_gain  \
# 11294                  ?        Husband  White    Male             0
# 22183  Machine-op-inspct        Husband  White    Male             0
# 9686               Sales        Husband  White    Male             0
# 19164              Sales  Not-in-family  White    Male             0
# 113                Sales           Wife  White  Female          4064
#
#        capital_loss  hours_per_week native_country salary
# 11294             0              40       Portugal  <=50K
# 22183             0              40  United-States  <=50K
# 9686              0              40  United-States   >50K
# 19164             0              40  United-States  <=50K
# 113               0              25  United-States  <=50K

# %%
capital_gain_new = pd.to_numeric(df['capital_gain'])

# %%
# Your Code is Here

plt.figure(figsize=(6, 4))
sns.set_style('whitegrid')
sns.boxplot(x=capital_gain_new, data=df, showmeans=False);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/6Xj1TCz/US-Citizens17.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here
plt.rcParams["figure.figsize"] = (6, 4)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.kdeplot(data=df, x=capital_gain_new, fill=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/X3nW72Q/US-Citizens18.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df['capital_gain'].describe()
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %% [raw]
# Desired Output:
#
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here
sns.set_style('whitegrid')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.boxplot(data=df, x='salary', y=capital_gain_new, showmeans=False)
# Out:
# <Axes: xlabel='salary', ylabel='capital_gain'>

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/CM3cTgt/19.png)

# %%
# Your Code is Here
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.kdeplot(data=df, x=capital_gain_new, hue='salary', fill=True);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/h7DKvLY/20.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby('salary')['capital_gain'].describe()
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/mzYxTD4/21.png)

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_gain not equal the zero**

# %%
# Your Code is Here
df[df['capital_gain'] != 0].groupby('salary')['capital_gain'].describe()
# Out:
#           count      mean       std      min      25%      50%       75%  \
# salary
# <=50K  1035.000  3552.813  3173.419  114.000 2202.000 3273.000  4101.000
# >50K   1677.000 18731.165 26778.676 3103.000 7298.000 7896.000 15024.000
#
#              max
# salary
# <=50K  41310.000
# >50K   99999.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/r3mdBkK/22.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result** Based on the analysis results, we can draw the following conclusions:
#
# Distribution of Capital Gain: We observe that the average capital gain is approximately 5 times higher in the >50K salary level compared to the <=50K salary level. This indicates that individuals with higher salaries tend to have higher capital gains.
#
# Statistical Distribution: The capital gain distribution for individuals in the >50K salary group has a larger standard deviation, indicating that capital gains are spread over a wider range within this group.
#
# Median Values: The median values of capital gain are quite different for both salary groups. This suggests that individuals earning >50K salaries generally have higher capital gains, with high median values within this group.
#
# Explanatory Power: Capital gain can be a strong explanatory variable for predicting salary levels. Especially in the >50K salary level, a higher capital gain often indicates a higher income level. However, in the <=50K salary level, lower capital gains are more common, indicating that individuals with lower incomes benefit less from capital gains.

# %% [markdown]
# ### capital_loss

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here
plt.figure(figsize=(6, 4))
sns.boxplot(data=df, x='capital_loss', showmeans=False)
# Out:
# <Axes: xlabel='capital_loss'>

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Db3XHKz/23.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here
sns.kdeplot(data=df, x='capital_loss', fill=True, palette='tab10')
# Out:
# <Axes: xlabel='capital_loss', ylabel='Density'>

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/z7P15zX/24.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df['capital_loss'].describe()
# Out:
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %% [raw]
# Desired Output:
#
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here
sns.boxplot(data=df, x='salary', y='capital_loss', showmeans=False)
# Out:
# <Axes: xlabel='salary', ylabel='capital_loss'>

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Dr7Bv9V/25.png)

# %%
# Your Code is Here
sns.kdeplot(data=df, x='capital_loss', hue= 'salary', fill=True, palette='tab10')
# Out:
# <Axes: xlabel='capital_loss', ylabel='Density'>

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/4Vg5Zyy/26.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby('salary')['capital_loss'].describe()
# Out:
#            count    mean     std   min   25%   50%   75%      max
# salary
# <=50K  24698.000  53.190 310.890 0.000 0.000 0.000 0.000 4356.000
# >50K    7839.000 195.051 595.555 0.000 0.000 0.000 0.000 3683.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/h9DTKNW/27.png)

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_loss not equel the zero**

# %%
# Your Code is Here

df[df['capital_loss'] != 0].groupby('salary')['capital_loss'].describe()
# Out:
#          count     mean     std     min      25%      50%      75%      max
# salary
# <=50K  746.000 1760.983 438.906 155.000 1590.000 1721.000 1980.000 4356.000
# >50K   773.000 1978.017 264.144 653.000 1887.000 1902.000 1977.000 3683.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/gJzQvmD/28.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :**
# Based on the analysis results for capital-loss with respect to salary levels, we can draw the following conclusions:
#
# Distribution of Capital Loss: The average capital loss for individuals earning >50K is slightly higher compared to those earning <=50K. This suggests that individuals with higher salaries may experience slightly higher capital losses on average.
#
# Variability in Capital Loss: The standard deviation of capital loss for both salary groups is relatively low, indicating that the variability in capital losses within each group is limited. However, individuals earning >50K have a slightly larger standard deviation, implying slightly more variability in capital losses within this group.
#
# Median Values: The median capital loss values for both salary groups are relatively close to each other. This suggests that there may not be a significant difference in the central tendency of capital losses between individuals earning <=50K and >50K.
#
# Interpretation: Capital loss may not be as strong of an indicator for predicting salary levels as capital gain. The similarity in median values and relatively low variability within each group suggests that capital loss may not provide as much explanatory power in distinguishing between salary levels compared to capital gain. However, further analysis and consideration of other factors may be necessary to fully understand the relationship between capital loss and salary levels.

# %% [markdown]
# ### hours_per_week

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
# Your Code is Here

sns.boxplot(data=df, x='hours_per_week', palette='tab10', showmeans=False);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/TkNCRYY/29.png)

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here
sns.kdeplot(data=df, x='hours_per_week', fill=True, palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/tsp5GXb/30.png)

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df['hours_per_week'].describe()
# Out:
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %% [raw]
# Desired Output:
#
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(data=df, y='hours_per_week', x='salary', showmeans=False);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/4RhSct7/31.png)

# %%
# Your Code is Here

sns.kdeplot(data=df, x='hours_per_week', hue='salary', fill=True)
# Out:
# <Axes: xlabel='hours_per_week', ylabel='Density'>

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/pbbVnMG/32.png)

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby('salary')['hours_per_week'].describe()
# Out:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K    7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/6NbWfzz/33.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result**
# From the analysis results for 'hours-per-week' with respect to salary levels, we can draw the following conclusions:
#
# Mean Hours Worked: The mean hours worked per week for individuals earning <=50K is lower (approximately 38.84 hours) compared to those earning >50K (approximately 45.47 hours). This suggests that individuals with higher salaries tend to work more hours per week on average.
#
# Variability in Hours Worked: The standard deviation of hours worked per week is relatively low for both salary groups, indicating that there is not a significant variability in the number of hours worked within each group. However, individuals earning >50K have a slightly larger standard deviation, implying slightly more variability in the number of hours worked within this group.
#
# Median Hours Worked: The median hours worked per week for both salary groups is similar, with individuals in both groups having a median of 40 hours worked per week. This suggests that, despite differences in mean hours worked, the central tendency of hours worked is similar between the two salary groups.
#
# Interpretation: The difference in mean hours worked between salary groups indicates that there may be a positive relationship between salary level and the number of hours worked per week. However, the similarity in median values suggests that, while individuals with higher salaries tend to work more hours on average, there is also a considerable overlap in the number of hours worked between salary groups. This indicates that factors other than just the number of hours worked may also influence salary levels.

# %% [markdown]
# ### See the relationship between each numeric features by target feature (salary) in one plot basically

# %%
numeric_columns = df.select_dtypes(include=[np.number])
plt.figure(figsize=(6, 4))
sns.pairplot(df, x_vars=numeric_columns, hue='salary', palette='crest', corner=True)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/N7Fz4hg/34.png)

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# ### education & education_num

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
df['education'].value_counts()
# Out:
# education
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
df['education_num'].value_counts()
# Out:
# education_num
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# NaN         802
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %% [raw]
# df.groupby('education')

# %% [raw]
# Desired Output:
#
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# Masters       14.000            1686
#               NaN                 36
# Preschool     1.000               49
#               NaN                  1
# Prof-school   15.000             559
#               NaN                 17
# Some-college  10.000            7089
#               NaN                193
# Name: education_num, dtype: int64

# %% [markdown]
# **Visualize the count of person in each categories for these features (education, education_num) separately**

# %%
# Your Code is Here
plt.figure(figsize=(6, 4))
sns.countplot(x='education', data=df)
plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5xc31HR/35.png)

# %%
# Your Code is Here

plt.figure(figsize=(6, 4))
sns.countplot(x='education_num', data=df);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/6HWtNN6/36.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these features (education and education_num) separately and visualize them with countplot**

# %%
# Your Code is Here

df.groupby(['education'])['salary'].value_counts()
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# Name: salary, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6, 4))
plt.xticks(rotation=90);

sns.countplot(data=df, x='education', hue='salary', palette='tab10')
plt.legend(loc='upper center');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/qxZXX1y/37.png)

# %%
# Your Code is Here

df.groupby(['education_num'])['salary'].value_counts()
# Out:
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         >50K       935
#                <=50K      751
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
#                <=50K      103
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         >50K       935
#                <=50K      751
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
#                <=50K      103
# Name: salary, dtype: int64

# %%
# Your Code is Here
sns.set(font_scale=0.8)
plt.figure(figsize=(6, 4))
sns.set_style('whitegrid')
sns.countplot(data=df, x='education_num', hue='salary', palette='tab10');
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad: 'float' = 1.08, h_pad: 'float | None' = None, w_pad: 'float | None' = None, rect: 'tuple[float, float, float, float] | None' = None) -> 'None'>

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/2M0BYyk/38.png)

# %% [markdown]
# **Visualize the boxplot of "education_num" feature by "salary" levels**

# %%
# Your Code is Here
sns.set(font_scale=0.8)
plt.figure(figsize=(6, 4))
sns.boxplot(data=df, x='salary', y='education_num', showmeans=False, palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/mSBNzKw/39.png)

# %% [markdown]
# **Decrease the number of categories in "education" feature as low, medium, and high level and create a new feature with this new categorical data.**

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
df['education'].apply(mapping_education).value_counts()
# Out:
# education
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: education, dtype: int64

# %%
# By using "mapping_education" def function above, create a new column named "education_summary"
# Your Code is Here

df['education_summary'] = df['education'].apply(mapping_education)

# %% [markdown]
# **Visualize the count of person in each categories for these new education levels (high, medium, low)**

# %%
# Your Code is Here
sns.set_style('whitegrid')
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='education_summary', palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/cx3Dzn1/40.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these new education levels(high, medium, low) and visualize it with countplot**

# %%
# Your Code is Here
df.groupby(['education_summary'])['salary'].value_counts()
# Out:
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
# Your Code is Here
sns.set_style('whitegrid')
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='education_summary', hue='salary', palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/tXk04LJ/41.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new education levels (high, medium, low) and visualize it with pie plot separately**

# %%
# Your Code is Here
percentage_education_summary = df.groupby(['education_summary'])['salary'].value_counts(normalize=True)

# %% [raw]
# Desired Output:
#
# education_summary   salary
# high_level_grade    <=50K    0.515
#                     >50K     0.485
# low_level_grade     <=50K    0.943
#                     >50K     0.057
# medium_level_grade  <=50K    0.818
#                     >50K     0.182
# Name: salary, dtype: float64

# %%
df['education_summary'].unique()
# Out:
# array(['high_level_grade', 'medium_level_grade', 'low_level_grade'],
#       dtype=object)

# %%
# Your Code is Here
percentage_education_summary = df.groupby(['education_summary'])['salary'].value_counts(normalize=True)
education_summaries = df['education_summary'].unique()



fig, axs = plt.subplots(1, 3, figsize=(10, 4))  
mycolors = ['pink', '#86c9eb']

for i, education_summary in enumerate(['high_level_grade','low_level_grade', 'medium_level_grade']):
    data = percentage_education_summary[education_summary]
    labels = data.index
    sizes = data.values * 100 
    axs[i].set_title(education_summary)  
    axs[i].pie(sizes, labels=labels, autopct='%1.2f%%', colors=mycolors, startangle=360)
    axs[i].axis('equal')
    axs[i].set_ylabel('salary')

plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/9W6kXc6/42.png)

# %% [markdown]
# **Check the count of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby(['salary'])['education_summary'].value_counts()
# Out:
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='salary', hue='education_summary', palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/K9xLxvF/43.png)

# %% [markdown]
# **Check the the percentage distribution of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

percentage = df.groupby(['salary'])['education_summary'].value_counts(normalize=True)
percentage
# Out:
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  education_summary
# <=50K   medium_level_grade   0.670
#         high_level_grade     0.168
#         low_level_grade      0.162
# >50K    high_level_grade     0.499
#         medium_level_grade   0.470
#         low_level_grade      0.031
# Name: education_summary, dtype: float64

# %%
percentage_salary_summary = df.groupby(['salary'])['education_summary'].value_counts(normalize=True)
salaries = df['salary'].unique()

fig, axs = plt.subplots(1, 2, figsize=(8, 4))  
mycolors = ['pink', '#86C9EB', '#7DE376']
for i, salary in enumerate(salaries):
    data = percentage_salary_summary[salary]
    if i == 0:
        labels =['(<=50, low_level_grade)', '(<=50, medium_level_grade)', '(<=50, high_level_grade)']
    else:
        labels = ['(>50, low_level_grade)', '(>50, medium_level_grade)', '(>50, high_level_grade)']
    
    sizes = data.values * 100 
    axs[i].set_title(salary) 
    axs[i].pie(sizes, labels=labels, autopct='%1.2f%%', colors=mycolors, startangle=360)
    axs[i].axis('equal')
    axs[i].set_ylabel('education_summary') 

plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/42pnNPc/44.png)

# %%
df.groupby([ 'salary','education_summary']).size() / df.groupby('salary').size()
# Out:
# salary  education_summary
# <=50K   high_level_grade     0.168
#         low_level_grade      0.162
#         medium_level_grade   0.670
# >50K    high_level_grade     0.499
#         low_level_grade      0.031
#         medium_level_grade   0.470
# dtype: float64

# %%
my_df = df.groupby('salary')['education_summary'].value_counts(normalize = True).reset_index()
my_df['percentage'] = my_df['proportion']
my_df.sort_values(by = ['salary', 'education_summary'])
my_df.drop(columns = 'proportion').sort_values(by = ['salary', 'education_summary'])
# Out:
#   salary   education_summary  percentage
# 1  <=50K    high_level_grade       0.168
# 2  <=50K     low_level_grade       0.162
# 0  <=50K  medium_level_grade       0.670
# 3   >50K    high_level_grade       0.499
# 5   >50K     low_level_grade       0.031
# 4   >50K  medium_level_grade       0.470

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/jHYrhz8/45.png)

# %%
# Your Code is Here
percentage_salary_summary = df.groupby(['salary'])['education_summary'].value_counts(normalize=True)

fig, axs = plt.subplots(1, 2, figsize=(16, 4))
mycolors = ['#7DE376', 'pink', '#86C9EB']
for i, salary in enumerate(my_df['salary'].unique()):
    data = percentage_salary_summary[salary]
    labels = data.index
    short_labels= [label.split('_')[0] for label in labels]
    sizes = data.values * 100 
   
    axs[i].set_title(salary, pad=15) 
    axs[i].pie(sizes, labels=short_labels, autopct='%1.2f%%', colors=mycolors, startangle=120)
    axs[i].axis('equal')
    axs[i].set_ylabel('percentage') 


plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5BnYV6h/46.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :**
# From the analysis of the salary distribution across different education levels, the following conclusions can be drawn:
#
# Salary Distribution by Education Level:
#
# The majority of individuals with salaries less than or equal to $50K are distributed across all three education levels: high level, medium level, and low level.
# For individuals earning more than $50K, the distribution is also spread across all three education levels, but with a higher proportion having a high-level education compared to those with medium or low levels of education.
# Effect of Education on Salary:
#
# Individuals with a higher level of education tend to have a higher likelihood of earning a salary above $50K compared to those with lower levels of education.
# However, even within each education level, there are individuals earning both below and above $50K, indicating that education level is not the sole determinant of salary.
# Significance of Education Level:
#
# The proportion of individuals with a high-level education earning above $50K is notably higher compared to those with medium or low levels of education.
# This suggests that obtaining a high-level education may increase the likelihood of securing higher-paying job opportunities.
# Overall, while education level appears to have a significant influence on salary, other factors such as experience, skills, industry, and geographical location may also play crucial roles in determining an individual's earning potential. Therefore, a holistic approach considering various factors is essential for understanding salary distribution accurately.

# %% [markdown]
# ### marital_status & relationship

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
# Your Code is Here

df['marital_status'].value_counts()
# Out:
# marital_status
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
# Your Code is Here

df['relationship'].value_counts()
# Out:
# relationship
# Husband           13187
# Not-in-family      8292
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
# Fill missing values with "Unknown" in the column of "relationship"

# Your Code is Here

df['relationship'].fillna('Unknown', inplace=True)

# %%
# Your Code is Here

df.groupby('relationship')['marital_status'].value_counts()
# Out:
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unknown         Never-married             4481
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
#                 Married-spouse-absent       45
#                 Widowed                     15
#                 Married-AF-spouse            1
# Unmarried       Divorced                  1600
#                 Never-married              881
#                 Separated                  451
#                 Widowed                    383
#                 Married-spouse-absent      130
# Wife            Married-civ-spouse        1556
#                 Married-AF-spouse           12
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unknown         Never-married             4481
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
#                 Married-spouse-absent       45
#                 Widowed                     15
#                 Married-AF-spouse            1
# Unmarried       Divorced                  1600
#                 Never-married              881
#                 Separated                  451
#                 Widowed                    383
#                 Married-spouse-absent      130
# Wife            Married-civ-spouse        1556
#                 Married-AF-spouse           12
# Name: marital_status, dtype: int64

# %% [markdown]
# **Assessment :**
# The provided data presents a breakdown of individuals based on their relationship status and marital status. Let's analyze each feature separately and then assess their combined influence.
#
# Relationship:
# Husband: This category primarily consists of individuals who are in a marital relationship where the husband is present. The majority are classified as 'Married-civ-spouse', indicating a civilian marriage, with a substantial count of 13178. There are also a few instances classified under 'Married-AF-spouse', which might represent marriages within the Armed Forces, albeit in a minority (9 instances).
#
# Not-in-family: This category encompasses individuals who are not part of a family unit. The majority here are 'Never-married' (4694 instances), suggesting they have never been married. Other significant subcategories include 'Divorced', 'Widowed', 'Separated', and 'Married-spouse-absent', each indicating different statuses of familial relationships or lack thereof.
#
# Other-relative: These are individuals who are related to someone in the family but don't fit into the previous categories. The majority are 'Never-married', indicating a significant portion of unmarried relatives. However, there are also instances of individuals classified under various marital statuses, such as 'Married-civ-spouse', 'Divorced', 'Separated', 'Widowed', and 'Married-spouse-absent'.
#
# Unknown: This category comprises individuals with relationship statuses that are not clearly defined. The majority are 'Never-married', 'Divorced', or 'Separated', with smaller counts in other categories. The label 'Unknown' suggests some ambiguity in the data or uncertainty about the relationship status.
#
# Unmarried: This category represents individuals who are not married. The majority fall under 'Divorced' and 'Never-married', indicating a significant portion of the unmarried population. There are also instances of 'Separated', 'Widowed', and 'Married-spouse-absent', reflecting various statuses within this group.
#
# Marital Status:
# Married-civ-spouse: This category denotes individuals who are in a civilian marriage. It's the most prevalent marital status among the provided data, with significant counts across different relationship categories such as 'Husband', 'Not-in-family', 'Other-relative', and 'Wife'.
#
# Married-AF-spouse: This category represents individuals married within the Armed Forces. The counts are relatively low compared to other marital statuses, with instances mainly found in 'Husband' and 'Wife' categories.
#
# Never-married: This category comprises individuals who have never been married. It's predominant in categories like 'Not-in-family' and 'Unmarried', reflecting the status of being single or unmarried.
#
# Divorced, Widowed, Separated: These categories represent individuals who have experienced the dissolution of marriage through divorce, death of a spouse, or separation, respectively. They are distributed across different relationship categories, indicating diverse experiences within these groups.
#
# Assessment:
# The data provides valuable insights into the distribution of relationship and marital statuses within the population. It reflects the diversity of familial arrangements and marital experiences present in the dataset. The prevalence of 'Married-civ-spouse' suggests that civilian marriages are the most common form of marital union. However, there are also significant counts of individuals who have never been married, indicating a substantial unmarried population. The presence of various marital statuses across different relationship categories highlights the complexity of familial relationships and the diversity of experiences within the dataset. Further analysis could explore demographic factors and their correlations with these relationship and marital statuses to gain deeper insights.

# %% [markdown]
# **Visualize the count of person in each categories**

# %%
# Your Code is Here
plt.figure(figsize=(6, 4))
plt.xticks(rotation=45);
sns.countplot(data=df, x='marital_status', palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/1RNHVvj/47.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by categories and visualize it with countplot**

# %%
# Your Code is Here

df.groupby('marital_status')['salary'].value_counts()
# Out:
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
# Your Code is Here
sns.set_style('whitegrid')
plt.figure(figsize=(6, 4))
plt.xticks(rotation=45);
sns.countplot(data=df, x='marital_status', hue='salary',  palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/qjNhW9h/48.png)

# %% [markdown]
# **Decrease the number of categories in "marital_status" feature as married, and unmarried and create a new feature with this new categorical data**

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
# Your Code is Here

df['marital_status'].apply(mapping_marital_status).value_counts()
# Out:
# marital_status
# unmarried    17126
# married      15411
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# unmarried    17126
# married      15411
# Name: marital_status, dtype: int64

# %%
# By using "mapping_marital_status" def function above, create a new column named "marital_status_summary"

# Your Code is Here

df['marital_status_summary'] = df['marital_status'].apply(mapping_marital_status)

df['marital_status_summary']
# Out:
# 0        unmarried
# 1          married
# 2        unmarried
# 3          married
# 4          married
#            ...
# 32556      married
# 32557      married
# 32558    unmarried
# 32559    unmarried
# 32560      married
# Name: marital_status_summary, Length: 32537, dtype: object

# %% [markdown]
# **Visualize the count of person in each categories for these new marital status (married, unmarried)**

# %%
# Your Code is Here

plt.figure(figsize=(6, 4))

sns.countplot(data=df, x='marital_status_summary',  palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/wRjj6Bx/49.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these new marital status (married, unmarried) and visualize it with countplot**

# %%
# Your Code is Here

df.groupby('marital_status_summary')['salary'].value_counts()
# Out:
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6, 4))
sns.set_style('whitegrid')

sns.countplot(data=df, x='marital_status_summary', hue='salary',  palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0JtYnFb/50.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new marital status (married, unmarried) and visualize it with pie plot separately**

# %%
# Your Code is Here

percentage_marital_status_summary = df.groupby(['marital_status_summary'])['salary'].value_counts(normalize=True)
percentage_marital_status_summary
# Out:
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %%
# Your Code is Here

percentage_marital_status_summary = df.groupby(['marital_status_summary'])['salary'].value_counts(normalize=True)

salaries = df['salary'].unique()

fig, axs = plt.subplots(1, len(salaries), figsize=(8, 4))
mycolors = ['pink', '#86c9eb']

for i, marital_status_summary in enumerate(df['marital_status_summary'].unique()[::-1]):
    data = percentage_marital_status_summary[marital_status_summary]
    labels = data.index
    sizes = data.values * 100 
    axs[i].set_title(f'{marital_status_summary}')
    axs[i].pie(sizes, labels=labels, autopct='%1.2f%%', colors=mycolors, startangle=360)
    axs[i].set_ylabel('salary')
    axs[i].axis('equal')
  
    plt.tight_layout;

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/TYxT5Zz/51.png)

# %% [markdown]
# **Check the count of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby('salary')['marital_status_summary'].value_counts()
# Out:
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: marital_status_summary, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='salary', hue='marital_status_summary', palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/YWjjsZP/52.png)

# %% [markdown]
# **Check the the percentage distribution of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby('salary')['marital_status_summary'].value_counts(normalize=True)
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %%
# Your Code is Here

my_df = df.groupby('salary')['marital_status_summary'].value_counts(normalize = True).reset_index()
my_df['percentage'] = my_df['proportion']
my_df.sort_values(by = ['salary', 'marital_status_summary'])
my_df.drop(columns = 'proportion').sort_values(by = ['salary', 'marital_status_summary'])
# Out:
#   salary marital_status_summary  percentage
# 1  <=50K                married       0.351
# 0  <=50K              unmarried       0.649
# 2   >50K                married       0.859
# 3   >50K              unmarried       0.141

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Swb4rb7/v53.png)

# %%
# Your Code is Here

salaries = my_df['salary'].unique()

fig, axs = plt.subplots(1, 2, figsize=(7, 4))  
mycolors = ['pink', '#86c9eb']

for i, salary in enumerate(salaries):
    data = my_df[my_df['salary'] == salary]['percentage']
    labels = my_df[my_df['salary'] == salary]['marital_status_summary']
    if i == 0:
        mycolors = ['#86c9eb', 'pink']
    else:
        mycolors = ['pink', '#86c9eb']
    sizes = data.values * 100 
    axs[i].set_title(salary) 
    axs[i].pie(sizes, labels=labels, autopct='%1.2f%%', colors=mycolors, startangle=120+(i+1))
    axs[i].axis('equal')
    axs[i].set_ylabel('percentage') 

plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/cJxmqwG/54.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :**
# Here are some conclusions drawn from the analysis:
#
# Impact of Marital Status on Salary:
#
# The majority of individuals earning $50,000 or less are unmarried. Unmarried individuals have a larger proportion within this salary range.
# A significant majority of individuals earning more than $50,000 are married. It's observed that married individuals have a higher proportion within this salary range.
# Salary Disparity between Married and Unmarried Individuals:
#
# Married individuals have a distinct advantage in the likelihood of earning over $50,000. Unmarried individuals have a lower proportion within this income bracket.
# This suggests that being married might be a positive factor for increasing one's salary.
# Relationship between Marriage and Salary:
#
# The higher likelihood of married individuals reaching higher salary ranges suggests that marriage may promote economic stability.
# However, this analysis should be conducted considering other variables, as there are many factors influencing salary, and drawing definitive conclusions based solely on marital status may not be accurate.

# %% [markdown]
# ### workclass

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df['workclass'].value_counts()
# Out:
# workclass
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6, 4))
plt.xticks(rotation=90)
sns.countplot(data=df, x='workclass');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/NmKTp84/55.png)

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unkown"

# Your Code is Here

df['workclass'].replace('?', 'Unknown', inplace=True)

# %% [markdown]
# **Check the count of person in each "salary" levels by workclass groups and visualize it with countplot**

# %%
# Your Code is Here

df.groupby('workclass')['salary'].value_counts()
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
# Your Code is Here
sns.set_style('whitegrid')
plt.figure(figsize=(6, 4))
plt.xticks(rotation=90)

sns.countplot(data=df, x='workclass', hue='salary', palette='tab10')
plt.legend(loc='upper left', title='salary');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/bPnNvsn/56.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each workclass groups and visualize it with bar plot**

# %%
# Your Code is Here

df.groupby('workclass')['salary'].value_counts(normalize=True)
# Out:
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unknown           <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unknown           <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# Name: salary, dtype: float64

# %%
# Your Code is Here

my_df = df.groupby('workclass')['salary'].value_counts(normalize = True).reset_index()
my_df['percentage'] = my_df['proportion']
my_df.sort_values(by = ['salary', 'workclass'])
my_df.drop(columns = 'proportion', inplace=True)
my_df
# Out:
#            workclass salary  percentage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 7       Self-emp-inc   >50K       0.557
# 8       Self-emp-inc  <=50K       0.443
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13           Unknown  <=50K       0.896
# 14           Unknown   >50K       0.104
# 15       Without-pay  <=50K       1.000

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/8YvM14M/57.png)

# %%
# Your Code is Here

ax = sns.barplot(data=my_df, x='workclass', y='percentage', hue='salary', errorbar=None, palette='tab10')
for container in ax.containers:
    ax.bar_label(container, fmt='%1.2f', fontsize=8)
plt.legend(loc='upper left', title='salary')
plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/NFN5q04/58.png)

# %% [markdown]
# **Check the count of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby('salary')['workclass'].value_counts()
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='salary', hue='workclass')
plt.legend(loc='upper center', title='workclass');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/98V8zkN/59.png)

# %% [markdown]
# **Check the the percentage distribution of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

percentage = df.groupby('salary')['workclass'].value_counts(normalize=True)
percentage
# Out:
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unknown            0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unknown            0.024
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unknown            0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unknown            0.024
# Name: workclass, dtype: float64

# %%
# Your Code is Here

my_df = df.groupby('salary')['workclass'].value_counts(normalize = True).reset_index()
my_df['percentage'] = my_df['proportion']
my_df.sort_values(by = ['salary', 'workclass'])
my_df.drop(columns = 'proportion').sort_values(by = ['salary', 'workclass'])
# Out:
#    salary         workclass  percentage
# 5   <=50K       Federal-gov       0.024
# 3   <=50K         Local-gov       0.060
# 8   <=50K      Never-worked       0.000
# 0   <=50K           Private       0.717
# 6   <=50K      Self-emp-inc       0.020
# 1   <=50K  Self-emp-not-inc       0.074
# 4   <=50K         State-gov       0.038
# 2   <=50K           Unknown       0.067
# 7   <=50K       Without-pay       0.001
# 13   >50K       Federal-gov       0.047
# 12   >50K         Local-gov       0.079
# 9    >50K           Private       0.633
# 11   >50K      Self-emp-inc       0.079
# 10   >50K  Self-emp-not-inc       0.092
# 14   >50K         State-gov       0.045
# 15   >50K           Unknown       0.024

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/QcdnXpk/60.png)

# %%
# Your Code is Here
plt.figure(figsize=(10, 5))
workclass_index = df.workclass.value_counts().index.sort_values()
ax = sns.barplot(data=my_df, x='salary', y='percentage', hue=my_df.workclass, hue_order=workclass_index, ci=None, palette='tab10')
for container in ax.containers:
    ax.bar_label(container, fmt='%1.3f')
plt.legend(loc='upper left', title='workclass')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Kz5BDBj/61.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :**
# Based on the provided data, here are some conclusions that can be drawn:
#
# Income Distribution by Workclass: The majority of individuals (<=50K) work in the private sector, followed by self-employment (not incorporated), and then local government. Among those earning >50K, the distribution is similar, with the majority working in the private sector, followed by self-employment (not incorporated) and local government.
#
# Proportion of High Earners: The percentage of individuals earning >50K is higher in self-employment (incorporated and not incorporated) compared to other workclasses.
#
# Low Proportion of High Earners in Public Sectors: Both in <=50K and >50K salary categories, the proportion of individuals working in federal, local, and state government jobs is relatively low compared to the private sector.
#
# Unknown and Never-worked Categories: The "Unknown" workclass has a non-negligible proportion of individuals in both income categories, indicating that there's a portion of the population where their work classification is not clearly defined. The "Never-worked" category only exists in the <=50K income bracket.
#
# Disparity in Income: There's a clear income disparity between different workclasses, with the private sector having a larger proportion of high earners compared to other workclasses.
#
# These conclusions provide insights into the distribution of income across different workclasses, highlighting disparities and patterns in earning potential based on work classification.

# %% [markdown]
# ### occupation

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6, 4))
plt.xticks(rotation=90)
sns.countplot(data=df, x='occupation');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/F3qqLjS/62.png)

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unknown"

# Your Code is Here

df['occupation'].replace('?', 'Unknown', inplace=True)

# %% [markdown]
# **Check the count of person in each "salary" levels by occupation groups and visualize it with countplot**

# %%
# Your Code is Here

df.groupby('occupation')['salary'].value_counts()
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
#                    >50K       320
# Unknown            <=50K     1652
#                    >50K       191
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
#                    >50K       320
# Unknown            <=50K     1652
#                    >50K       191
# Name: salary, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6, 4))
plt.xticks(rotation=90)
sns.countplot(data=df, x='occupation', hue='salary', palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/RhkhQCW/63.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each occupation groups and visualize it with bar plot**

# %%
# Your Code is Here
df.groupby('occupation')['salary'].value_counts(normalize=True)
# Out:
# occupation         salary
# Adm-clerical       <=50K    0.865
#                    >50K     0.135
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.124
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
#                    >50K     0.305
# Transport-moving   <=50K    0.800
#                    >50K     0.200
# Unknown            <=50K    0.896
#                    >50K     0.104
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# occupation         salary
# Adm-clerical       <=50K    0.865
#                    >50K     0.135
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.124
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
#                    >50K     0.305
# Transport-moving   <=50K    0.800
#                    >50K     0.200
# Unknown            <=50K    0.896
#                    >50K     0.104
# Name: salary, dtype: float64

# %%
# Your Code is Here

df1 = df.groupby('occupation')['salary'].value_counts(normalize = True).reset_index()
df1['percentage'] = df1['proportion']
df1.sort_values(by = ['occupation', 'salary'])
df1.drop(columns = 'proportion').sort_values(by = ['occupation', 'salary'])
# Out:
#            occupation salary  percentage
# 0        Adm-clerical  <=50K       0.865
# 1        Adm-clerical   >50K       0.135
# 2        Armed-Forces  <=50K       0.889
# 3        Armed-Forces   >50K       0.111
# 4        Craft-repair  <=50K       0.773
# 5        Craft-repair   >50K       0.227
# 6     Exec-managerial  <=50K       0.516
# 7     Exec-managerial   >50K       0.484
# 8     Farming-fishing  <=50K       0.884
# 9     Farming-fishing   >50K       0.116
# 10  Handlers-cleaners  <=50K       0.937
# 11  Handlers-cleaners   >50K       0.063
# 12  Machine-op-inspct  <=50K       0.875
# 13  Machine-op-inspct   >50K       0.124
# 14      Other-service  <=50K       0.958
# 15      Other-service   >50K       0.042
# 16    Priv-house-serv  <=50K       0.993
# 17    Priv-house-serv   >50K       0.007
# 18     Prof-specialty  <=50K       0.551
# 19     Prof-specialty   >50K       0.449
# 20    Protective-serv  <=50K       0.675
# 21    Protective-serv   >50K       0.325
# 22              Sales  <=50K       0.731
# 23              Sales   >50K       0.269
# 24       Tech-support  <=50K       0.695
# 25       Tech-support   >50K       0.305
# 26   Transport-moving  <=50K       0.800
# 27   Transport-moving   >50K       0.200
# 28            Unknown  <=50K       0.896
# 29            Unknown   >50K       0.104

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/mb7JS3n/64.png)

# %%
# Your Code is Here
plt.figure(figsize=(10, 5))

ax = sns.barplot(data=df1, x='occupation', y='percentage', hue='salary', palette='tab10', errorbar=None)

for container in ax.containers:
    ax.bar_label(container, fmt='%1.2f', fontsize=8)
plt.legend(loc='upper right', title='salary')
plt.xticks(rotation=90);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/sW2b8wL/65.png)

# %% [markdown]
# **Check the count of person in each occupation groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby('salary')['occupation'].value_counts()
# Out:
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknown              1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknown               191
#         Other-service         137
#         Farming-fishing       115
#         Handlers-cleaners      86
#         Armed-Forces            1
#         Priv-house-serv         1
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknown              1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknown               191
#         Other-service         137
#         Farming-fishing       115
#         Handlers-cleaners      86
#         Armed-Forces            1
#         Priv-house-serv         1
# Name: occupation, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(12, 5))

sns.countplot(data=df, x='salary', hue='occupation')
plt.legend(loc='upper right', title='occupation');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/cvHS3FH/66.png)

# %% [markdown]
# **Check the the percentage distribution of person in each occupation groups by "salary" levels and visualize it with bar plot**

# %%
# Your Code is Here

df.groupby('salary')['occupation'].value_counts(normalize=True)
# Out:
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         Unknown             0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         Unknown             0.024
#         Other-service       0.017
#         Farming-fishing     0.015
#         Handlers-cleaners   0.011
#         Priv-house-serv     0.000
#         Armed-Forces        0.000
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         Unknown             0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         Unknown             0.024
#         Other-service       0.017
#         Farming-fishing     0.015
#         Handlers-cleaners   0.011
#         Armed-Forces        0.000
#         Priv-house-serv     0.000
# Name: occupation, dtype: float64

# %%
# Your Code is Here

df2 = df.groupby('salary')['occupation'].value_counts(normalize = True).reset_index()
df2['percentage'] = df2['proportion']
df2.sort_values(by = ['salary', 'occupation'])
df2.drop(columns = 'proportion').sort_values(by = ['salary', 'occupation'])
# Out:
#    salary         occupation  percentage
# 0   <=50K       Adm-clerical       0.132
# 14  <=50K       Armed-Forces       0.000
# 1   <=50K       Craft-repair       0.128
# 5   <=50K    Exec-managerial       0.085
# 10  <=50K    Farming-fishing       0.036
# 8   <=50K  Handlers-cleaners       0.052
# 6   <=50K  Machine-op-inspct       0.071
# 2   <=50K      Other-service       0.128
# 13  <=50K    Priv-house-serv       0.006
# 4   <=50K     Prof-specialty       0.092
# 12  <=50K    Protective-serv       0.018
# 3   <=50K              Sales       0.108
# 11  <=50K       Tech-support       0.026
# 9   <=50K   Transport-moving       0.052
# 7   <=50K            Unknown       0.067
# 19   >50K       Adm-clerical       0.065
# 29   >50K       Armed-Forces       0.000
# 18   >50K       Craft-repair       0.119
# 15   >50K    Exec-managerial       0.251
# 26   >50K    Farming-fishing       0.015
# 27   >50K  Handlers-cleaners       0.011
# 22   >50K  Machine-op-inspct       0.032
# 25   >50K      Other-service       0.017
# 28   >50K    Priv-house-serv       0.000
# 16   >50K     Prof-specialty       0.237
# 23   >50K    Protective-serv       0.027
# 17   >50K              Sales       0.125
# 21   >50K       Tech-support       0.036
# 20   >50K   Transport-moving       0.041
# 24   >50K            Unknown       0.024

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/7tK0PqX/67.png)

# %%
# Your Code is Here
plt.figure(figsize=(12, 4))
occupation_index = df.occupation.value_counts().index.sort_values()
ax = sns.barplot(data=df2, x='salary', y='percentage', hue='occupation', hue_order=occupation_index)
for container in ax.containers:
    ax.bar_label(container, fmt='%1.3f', fontsize=6)
plt.legend(loc = 'upper right', fontsize = 6, title = 'occupation', title_fontsize = 6)
plt.tight_layout
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/7brj34F/68.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :**
# From the analysis of the provided data on salary distribution across different occupations, we can draw several conclusions:
#
# Exec-managerial and Prof-specialty have higher percentages of >50K earners: Occupations such as Exec-managerial and Prof-specialty have a significantly higher proportion of individuals earning more than 50K annually compared to other occupations.
#
# Armed-Forces has no individuals earning >50K: The Armed-Forces occupation has no individuals earning more than 50K according to the provided data.
#
# Service and Blue-collar occupations predominantly have <=50K earners: Occupations such as Adm-clerical, Other-service, Craft-repair, Handlers-cleaners, and Machine-op-inspct have a higher percentage of individuals earning less than or equal to 50K annually.
#
# Tech-support and Sales have a mix of <=50K and >50K earners: These occupations have a relatively balanced distribution of individuals earning both less than or equal to 50K and more than 50K annually.
#
# Occupations like Priv-house-serv and Farming-fishing have a low percentage of >50K earners: These occupations have a very low percentage of individuals earning more than 50K annually, indicating lower average salaries within these fields.
#
# Unknown occupation has a relatively balanced distribution: The percentage of individuals earning <=50K and >50K in the Unknown occupation is relatively balanced, indicating uncertainty about the salary distribution within this category.
#
# These conclusions provide insights into the salary distribution across various occupations and can be valuable for understanding income disparities and workforce demographics.

# %% [markdown]
# ### race

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df['race'].value_counts()
# Out:
# race
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6, 4))
plt.xticks(rotation=45)
sns.countplot(data=df, x='race', palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/LdKct3G/69.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by races and visualize it with countplot**

# %%
# Your Code is Here

df.groupby('race')['salary'].value_counts()
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6, 4))
plt.xticks(rotation=45)
sns.countplot(data=df, x='race', hue='salary',  palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Qb4n8Y5/70.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each races and visualize it with pie plot**

# %%
df['race'].unique()
# Out:
# array(['White', 'Black', 'Asian-Pac-Islander', 'Amer-Indian-Eskimo',
#        'Other'], dtype=object)

# %%
# Your Code is Here
df.groupby('race')['salary'].value_counts(normalize=True)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: salary, dtype: float64

# %%
percentage = df.groupby('race')['salary'].value_counts(normalize=True)
races = df['race'].unique()
fig, axs = plt.subplots(2, 3, figsize=(12, 5))
mycolors = ['pink', '#86C9EB'] 
for i, race in enumerate([ 'Amer-Indian-Eskimo', 'Asian-Pac-Islander','Black', 'Other', 'White']):
    row = i // 3
    col = i % 3
    data= percentage[race]
    sizes = data.values*100
    labels = data.index
    axs[row, col].pie(sizes, labels=labels, autopct='%1.2f%%', colors=mycolors, startangle=360)
    axs[row, col].set_title(race) 
    
    axs[row, col].axis('equal')
    axs[row, col].set_ylabel('salary')

fig.delaxes(axs[1, 2])

plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/xsJWXp4/71.png)

# %% [markdown]
# **Check the count of person in each races by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby('salary')['race'].value_counts()
# Out:
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='salary', hue='race', palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/RBpPR38/72.png)

# %% [markdown]
# **Check the the percentage distribution of person in each races by "salary" levels and visualize it with bar plot**

# %%
# Your Code is Here

df.groupby('salary')['race'].value_counts(normalize=True)
# Out:
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %%
# Your Code is Here
df3 = df.groupby('salary')['race'].value_counts(normalize = True).reset_index()
df3['percentage'] = df3['proportion']
df3.sort_values(by = ['salary', 'race'])
df3.drop(columns = 'proportion').sort_values(by = ['salary', 'race'])
# Out:
#   salary                race  percentage
# 3  <=50K  Amer-Indian-Eskimo       0.011
# 2  <=50K  Asian-Pac-Islander       0.031
# 1  <=50K               Black       0.111
# 4  <=50K               Other       0.010
# 0  <=50K               White       0.837
# 8   >50K  Amer-Indian-Eskimo       0.005
# 7   >50K  Asian-Pac-Islander       0.035
# 6   >50K               Black       0.049
# 9   >50K               Other       0.003
# 5   >50K               White       0.908

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Xy9sYCY/73.png)

# %%
# Your Code is Here
plt.figure(figsize=(12, 4))
hue_order = [ 'Amer-Indian-Eskimo', 'Asian-Pac-Islander','Black', 'Other', 'White']
ax = sns.barplot(data=df3, x='salary', y='percentage', hue='race', hue_order=hue_order, palette='tab10')
for container in ax.containers:
    ax.bar_label(container, fmt='%1.3f', fontsize=8)
plt.legend(loc = 'upper left', title = 'race', fontsize=8)
plt.tight_layout
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/X8kf9NZ/74.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :**
# From the provided data, it seems to represent the distribution of salary brackets (<=50K and >50K) among different racial groups, along with the percentage of individuals in each racial group falling into each salary bracket.
#
# Conclusions drawn from the analysis could include:
#
# Distribution of Salary by Race: The data allows us to observe how different racial groups are distributed across different salary brackets. For example, it appears that the majority of individuals earning <=50K are White, while the majority of individuals earning >50K are also White.
#
# Disparities in Salary Distribution: Analyzing the percentages, we might observe disparities in salary distribution among racial groups. For instance, it seems that a higher percentage of White individuals earn >50K compared to other racial groups.
#
# Representation of Racial Groups: The data provides insight into the representation of various racial groups within different salary brackets, highlighting potential disparities or patterns in income distribution.
#
# Income Disparities: The data suggests potential income disparities between racial groups, with some groups being overrepresented or underrepresented in certain salary brackets compared to their overall population percentages.
#
# Need for Further Investigation: While the data provides a snapshot of the distribution of salary by race, drawing definitive conclusions about systemic issues or discrimination would require further analysis, considering factors such as education level, occupation, geographic location, and systemic biases.

# %% [markdown]
# ### gender

# %% [markdown]
# **Check the count of person in each gender and visualize it with countplot**

# %%
df.rename(columns={'sex' : 'gender'}, inplace=True)

# %%
# Your Code is Here

df['gender'].value_counts()
# Out:
# gender
# Male      21775
# Female    10762
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# Male      21775
# Female    10762
# Name: gender, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='gender', palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/GVTRbrb/75.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by gender and visualize it with countplot**

# %%
# Your Code is Here

df.groupby('gender')['salary'].value_counts()
# Out:
# gender  salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# gender  salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='gender', hue='salary', palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Nr8HRPk/76.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each gender and visualize it with pie plot**

# %%
# Your Code is Here

df.groupby('gender')['salary'].value_counts(normalize=True)
# Out:
# gender  salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# gender  salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %%
# Your Code is Here
percentage_gender = df.groupby('gender')['salary'].value_counts(normalize=True)
sex = df['gender'].unique()
salaries = df['salary'].unique()
mycolor = ['pink', '#86c9eb']
fig, axs = plt.subplots(1, 2, figsize=(10, 4))

for i, gender in enumerate(df['gender'].unique()[::-1]):
  
    data = percentage_gender[gender]
    labels = data.index
    sizes = data.values * 100
    axs[i].set_title(f'{gender}')
    axs[i].pie(sizes, labels=labels, colors=mycolor, autopct='%1.2f%%', startangle=360)
    axs[i].set_ylabel('salary')

plt.tight_layout()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/nrHj2jk/77.png)

# %% [markdown]
# **Check the count of person in each gender by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here
df.groupby('salary')['gender'].value_counts()
# Out:
# salary  gender
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  gender
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: gender, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='salary', hue='gender', palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/9sfsw11/78.png)

# %% [markdown]
# **Check the the percentage distribution of person in each gender by "salary" levels and visualize it with pie plot**

# %%
# Your Code is Here
df.groupby('salary')['gender'].value_counts(normalize=True)
# Out:
# salary  gender
# <=50K   Male     0.612
#         Female   0.388
# >50K    Male     0.850
#         Female   0.150
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  gender
# <=50K   Male     0.612
#         Female   0.388
# >50K    Male     0.850
#         Female   0.150
# Name: gender, dtype: float64

# %%
# Your Code is Here
percentage_sal = df.groupby('salary')['gender'].value_counts(normalize=True)
sex = df['gender'].unique()
salaries = df['salary'].unique()
mycolor = ['pink', '#86c9eb']
fig, axs = plt.subplots(1, 2, figsize=(10,4))

for i, salary in enumerate(salaries):
  
    data = percentage_sal[salary]
    labels = data.index
    sizes = data.values * 100
    axs[i].set_title(f'{salary}')
    axs[i].pie(sizes, labels=labels, colors=mycolor, autopct='%1.2f%%', startangle=360)
    axs[i].set_ylabel('gender')
    plt.tight_layout()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0DzhNgG/79.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :**
# From the provided data, which seems to represent the distribution of salary categories ("<=50K" and ">50K") among genders (Male and Female), we can draw the following conclusions:
#
# Income Distribution by Gender:
#
# Among males, approximately 61.2% have a salary less than or equal to $50K, while around 38.8% have a salary greater than $50K.
# Among females, the majority (around 85%) have a salary less than or equal to $50K, with only about 15% earning more than $50K.
# Gender Disparities in High-Income Groups:
#
# There seems to be a significant disparity between genders, especially in the ">50K" salary category. The proportion of males earning over $50K is considerably higher than that of females. Approximately 85% of individuals earning over $50K are males, while only about 15% are females.
# Income Equality:
#
# In the low-income category ("<=50K"), the distribution appears to be more balanced, with males constituting around 61.2% and females around 38.8%. However, in the high-income category (">50K"), the representation of females drops significantly, indicating potential gender inequality in higher salary brackets.
# Gender Bias or Disparities:
#
# The data suggests potential gender biases or disparities in terms of income distribution. The fact that a significantly higher proportion of males fall into the high-income category compared to females raises questions about gender equality and representation in higher-paying job roles or industries. Further investigation into the underlying factors contributing to this disparity may be warranted.
# Policy Implications:
#
# These findings could inform policies aimed at addressing gender disparities in the workforce, such as initiatives to promote equal pay, combat gender discrimination, and provide support for women's career advancement opportunities. Additionally, efforts to address systemic biases in hiring practices and promote diversity and inclusion in workplaces may be necessary to create more equitable income distributions across genders.

# %% [markdown]
# ### native_country

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df['native_country'].value_counts()
# Out:
# native_country
# United-States                 29153
# Mexico                          639
# Unknown                         582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: native_country, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10, 5))
plt.xticks(rotation=90)
sns.countplot(data=df, x='native_country');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/x3TNT7B/80.png)

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unknown"

# Your Code is Here

df['native_country'].replace('?', 'Unknown', inplace=True)

# %% [markdown]
# **Decrease the number of categories in "native_country" feature as US, and Others and create a new feature with this new categorical data**

# %%
def mapping_native_country(x):
    if x == "United-States":
        return "US"
    else:
        return "Others"

# %%
# Your Code is Here

df['native_country'].apply( mapping_native_country).value_counts()
# Out:
# native_country
# US        29153
# Others     3384
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# US        29153
# Others     3384
# Name: native_country, dtype: int64

# %%
# By using "mapping_native_country" def function above, create a new column named "native_country_summary"

# Your Code is Here
df["native_country_summary"] = df['native_country'].apply( mapping_native_country)

df["native_country_summary"]
# Out:
# 0            US
# 1            US
# 2            US
# 3            US
# 4        Others
#           ...
# 32556        US
# 32557        US
# 32558        US
# 32559        US
# 32560        US
# Name: native_country_summary, Length: 32537, dtype: object

# %% [raw]
# Desired Output:
#
# 0            US
# 1            US
# 2            US
# 3            US
# 4        Others
#           ...
# 32556        US
# 32557        US
# 32558        US
# 32559        US
# 32560        US
# Name: native_country_summary, Length: 32537, dtype: object

# %% [markdown]
# **Visualize the count of person in each new categories (US, Others)**

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
sns.countplot(data=df, x='native_country_summary', palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/wwDhVGd/81.png)

# %% [markdown]
# **Check the count of person in each "salary" levels by these new native countries (US, Others) and visualize it with countplot**

# %%
# Your Code is Here

df.groupby('native_country_summary')['salary'].value_counts()
# Out:
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6,4))
sns.countplot(data=df, x='native_country_summary', hue='salary', palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/SVnKp4k/82.png)

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new native countries (US, Others) and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby('native_country_summary')['salary'].value_counts(normalize=True)
# Out:
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: salary, dtype: float64

# %%
# Your Code is Here

percentage_native = df.groupby('native_country_summary')['salary'].value_counts(normalize=True)
native = df['native_country_summary'].unique()
salaries = df['salary'].unique()
mycolor = ['pink', '#86c9eb']
fig, axs = plt.subplots(1, 2, figsize=(10, 4))

for i, native_country_summary in enumerate(df['native_country_summary'].unique()[::-1]):
  
    data = percentage_native[native_country_summary]
    labels = data.index
    sizes = data.values * 100
    axs[i].set_title(f'{native_country_summary}')
    axs[i].pie(sizes, labels=labels, colors=mycolor, autopct='%1.2f%%', startangle=360)
    axs[i].set_ylabel('salary')

plt.tight_layout()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/4NQ5b1b/83.png)

# %% [markdown]
# **Check the count of person in each these new native countries (US, Others) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.groupby('salary')['native_country_summary'].value_counts()
# Out:
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: native_country_summary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='salary', hue='native_country_summary', palette='tab10');

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/c1gQfcg/84.png)

# %% [markdown]
# **Check the the percentage distribution of person in each these new native countries (US, Others) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

df.groupby('salary')['native_country_summary'].value_counts(normalize=True)
# Out:
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: native_country_summary, dtype: float64

# %%
# Your Code is Here

percentage_slry = df.groupby('salary')['native_country_summary'].value_counts(normalize=True)
native = df['native_country_summary'].unique()
salaries = df['salary'].unique()
mycolor = ['pink', '#86c9eb']
fig, axs = plt.subplots(1, 2, figsize=(11, 4))

for i, salary in enumerate(salaries):
  
    data = percentage_slry[salary]
    labels = data.index
    sizes = data.values * 100
    axs[i].set_title(f'{salary}')
    axs[i].pie(sizes, labels=labels, colors=mycolor, autopct='%1.2f%%', startangle=360)
    axs[i].set_ylabel('native_country_summary')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad: 'float' = 1.08, h_pad: 'float | None' = None, w_pad: 'float | None' = None, rect: 'tuple[float, float, float, float] | None' = None) -> 'None'>

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/QHc8m0x/85.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :**
# The given data represents the distribution of salary categories ("<=50K" and ">50K") across different countries. Based on this data, we can draw the following conclusions:
#
# High Income Ratio in the United States:
#
# In the high-income category (">50K"), the proportion of individuals working in the United States (US) is quite high (91.5%). This indicates that the US has a high income potential and economic opportunities.
#
# Low Income Ratio in Other Countries:
#
# In the salary category "<=50K", the proportion of individuals working in other countries is low (11%) compared to the ratio in the US (89.5%). This suggests that income levels in other countries are generally lower, and high-paying opportunities may be limited.
#
# More Balanced Income Distribution in the US:
#
# In the salary category "<=50K", the proportion of individuals working in the US is significantly higher compared to other countries. This indicates a more balanced distribution of both low and high-income levels in the US, while there may be more concentration in the low-income level in other countries.
#
# Economic Opportunities in the US:
#
# The high proportion in the high-income category suggests that economic opportunities in the US are attractive and have a high income potential. This implies that the workforce in the US may be seeking high-income opportunities and migrating to the country to capitalize on these opportunities.
#
# Economic Conditions in Other Countries:
#
# The low ratios in other countries' income categories suggest that economic conditions and job opportunities in these countries may be limited. The workforce in these countries may tend to migrate abroad in search of higher income opportunities.

# %% [markdown]
# <a id="5"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Other Specific Analysis Questions</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## Analysis Questions

# %% [markdown]
# ### What is the average age of males and females by income level?

# %%
avg_age = df.groupby(['salary', 'gender'])['age'].mean()
avg_age
# Out:
# salary  gender
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %% [raw]
# Desired Output:
#
# salary  gender
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %%
# Your Code is Here

avg_age = df.groupby(['salary', 'gender'])['age'].mean()

categories = [f"{salary}, {gender}" for salary, gender in avg_age.index]

plt.figure(figsize=(6, 4))
bars = plt.bar(categories, avg_age.values, width=0.5)
plt.xlabel('salary, gender')
plt.xticks(rotation=90, ha='right')

for bar, age in zip(bars, avg_age.values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{age:.2f}', ha='center', va='bottom')

plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/BBDy081/86.png)

# %%
# Your Code is Here
df4 = df.groupby(['salary', 'gender'])['age'].mean().reset_index()
df4
# Out:
#   salary  gender    age
# 0  <=50K  Female 36.217
# 1  <=50K    Male 37.149
# 2   >50K  Female 42.126
# 3   >50K    Male 44.627

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/4PD1208/87.png)

# %%
# Your Code is Here
plt.figure(figsize=(6, 4))
#hue_order = [ 'Amer-Indian-Eskimo', 'Asian-Pac-Islander','Black', 'Other', 'White']
ax = sns.barplot(data=df4, x='salary', y='age', hue='gender', palette='tab10')
for container in ax.containers:
    ax.bar_label(container, fmt='%1.2f', fontsize=8)
plt.legend(loc = 'upper left', title = 'gender', fontsize=8)
plt.tight_layout
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/2n0yGt7/88.png)

# %% [markdown]
# ### What is the workclass percentages of Americans in high-level income group?

# %%
# Your Code is Here
workclass_percentage = df[(df['salary'] == '>50K') & (df['native_country_summary'] == 'US')]['workclass'].value_counts(normalize=True) * 100
workclass_percentage
# Out:
# workclass
# Private            63.314
# Self-emp-not-inc    9.192
# Local-gov           8.021
# Self-emp-inc        7.784
# Federal-gov         4.687
# State-gov           4.547
# Unknown             2.455
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# Private            63.314
# Self-emp-not-inc    9.192
# Local-gov           8.021
# Self-emp-inc        7.784
# Federal-gov         4.687
# State-gov           4.547
# Unknown             2.455
# Name: workclass, dtype: float64

# %%
# Your Code is Here
workclass_percentage = df[(df['salary'] == '>50K') & (df['native_country_summary'] == 'US')]['workclass'].value_counts(normalize=True) * 100


plt.figure(figsize=(6, 4))
bars = plt.bar(workclass_percentage.index, workclass_percentage.values, width=0.8)

plt.xticks(rotation=45, ha='right')

for bar, percentage in zip(bars, workclass_percentage.values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{percentage:.2f}', ha='center', va='bottom')

plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/gMHzLgH/89.png)

# %% [markdown]
# ### What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %%
# Your Code is Here
df[(df['workclass'] == 'Private') & (df['salary'] == '>50K') & (df['native_country_summary'] == 'US')]['occupation'].value_counts(normalize=True) * 100
# Out:
# occupation
# Exec-managerial     26.438
# Prof-specialty      19.476
# Craft-repair        14.695
# Sales               14.475
# Adm-clerical         6.389
# Transport-moving     5.442
# Tech-support         4.428
# Machine-op-inspct    4.428
# Other-service        1.674
# Handlers-cleaners    1.344
# Farming-fishing      0.595
# Protective-serv      0.595
# Priv-house-serv      0.022
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# Exec-managerial     26.438
# Prof-specialty      19.476
# Craft-repair        14.695
# Sales               14.475
# Adm-clerical         6.389
# Transport-moving     5.442
# Tech-support         4.428
# Machine-op-inspct    4.428
# Other-service        1.674
# Handlers-cleaners    1.344
# Farming-fishing      0.595
# Protective-serv      0.595
# Priv-house-serv      0.022
# Name: occupation, dtype: float64

# %%
# Your Code is Here
occ_per = df[(df['workclass'] == 'Private') & (df['salary'] == '>50K') & (df['native_country_summary'] == 'US')]['occupation'].value_counts(normalize=True) * 100
plt.figure(figsize=(6, 4))
bars = plt.bar(occ_per.index, occ_per.values)
plt.xticks(rotation=90)
for bar, percentage in zip(bars, occ_per.values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{percentage:.2f}', ha='center', va='bottom', fontsize=8)

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/s3Kd7VS/90.png)

# %% [markdown]
# ### What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %%
# Your Code is Here

df[(df['salary'] == '>50K') & (df['race'] == 'Asian-Pac-Islander')]['education'].value_counts(normalize=True) * 100
# Out:
# education
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 10th            0.362
# 12th            0.362
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 10th            0.362
# 12th            0.362
# Name: education, dtype: float64

# %%
# Your Code is Here
edu_per = df[(df['salary'] == '>50K') & (df['race'] == 'Asian-Pac-Islander')]['education'].value_counts(normalize=True) * 100
plt.figure(figsize=(6, 4))
bars = plt.bar(edu_per.index, edu_per.values)
plt.xticks(rotation=90)
for bar, percentage in zip(bars, edu_per.values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{percentage:.2f}', ha='center', va='bottom', fontsize=8)

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/rZnSFBX/91.png)

# %% [markdown]
# ### What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %%
# Your Code is Here
df[(df['race'] == 'Asian-Pac-Islander') & (df['education'] == 'Bachelors') & (df['salary'] == '>50K')]['occupation'].value_counts(normalize=True) * 100
# Out:
# occupation
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: proportion, dtype: float64

# %% [raw]
# Desired Output:
#
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: occupation, dtype: float64

# %%
# Your Code is Here

occu_per = df[(df['race'] == 'Asian-Pac-Islander') & (df['education'] == 'Bachelors') & (df['salary'] == '>50K')]['occupation'].value_counts(normalize=True) * 100
plt.figure(figsize=(6, 4))
bars = plt.bar(occu_per.index, occu_per.values)
plt.xticks(rotation=90)
for bar, percentage in zip(bars, occu_per.values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{percentage:.2f}', ha='center', va='bottom', fontsize=8)

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/zZVsbJf/92.png)

# %% [markdown]
# ### What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %%
# Your Code is Here

mycolors = ['pink','#86C9EB']
plot = sns.catplot(data=df, kind="bar", x="education_summary", y="hours_per_week", hue="gender", col="marital_status_summary",
                   row="native_country_summary", palette=mycolors, errorbar=None, legend_out=True, aspect=1.5,
                   height=3)

for ax in plot.axes.flat:
    for p in ax.patches:
        ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.subplots_adjust(top=0.9)
plt.suptitle("Working Hours Per Week by Gender for Education, Native Country, Marital Status", fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/G5KY8nf/93.png)

# %% [markdown]
# <a id="6"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Dropping Similar & Unneccessary Features</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# Your Code is Here

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32537 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education-num           31735 non-null  float64
#  5   marital-status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            27473 non-null  object
#  8   race                    32537 non-null  object
#  9   sex                     32537 non-null  object
#  10  capital-gain            32537 non-null  int64
#  11  capital-loss            32537 non-null  int64
#  12  hours-per-week          32537 non-null  int64
#  13  native-country          32537 non-null  object
#  14  salary                  32537 non-null  object
#  15  marital_status_summary  32537 non-null  object
#  16  native_country_summary  32537 non-null  object
#  17  education_summary       32537 non-null  object
# dtypes: float64(1), int64(5), object(12)
# memory usage: 4.7+ MB

# %% [raw]
# Desired Output:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           31735 non-null  float64
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            32537 non-null  object
#  8   race                    32537 non-null  object
#  9   gender                  32537 non-null  object
#  10  capital_gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
#  14  salary                  32537 non-null  object
#  15  education_summary       32537 non-null  object
#  16  marital_status_summary  32537 non-null  object
#  17  native_country_summary  32537 non-null  object
# dtypes: float64(1), int64(5), object(12)
# memory usage: 5.7+ MB

# %%
# Drop the columns of "education", "education_num", "relationship", "marital_status", "native_country" permanently

# Your Code is Here
df.drop(columns=['education', 'education-num', 'relationship', 'marital-status', 'native-country'], inplace=True)
# Out:
#   Cell In[76], line 4
#     df.drop(columns=['education, 'education-num', 'relationship', marital-status', native-country'
#                                                                                                  ^
# SyntaxError: unterminated string literal (detected at line 4)

# %% [markdown]
# <a id="7"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Handling with Missing Value</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# **Check the missing values for all features basically**

# %%
# Your Code is Here

df.isnull().any().sum()

# %% [raw]
# Desired Output:
#
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %% [markdown]
# **1. It seems that there is no missing value. But we know that "workclass", and "occupation" features have missing values as the "Unknown" string values. Examine these features in more detail.**
#
# **2. Decide if drop these "Unknown" string values or not**

# %%
# Your Code is Here
df['workclass'].value_counts()
# Out:
# workclass
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Your Code is Here
df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: count, dtype: int64

# %% [raw]
# Desired Output:
#
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknown              1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# Unknown         1836
# Never-worked       7
# Name: workclass, dtype: int64

# %%
# Replace "Unknown" values with NaN using numpy library

# Your Code is Here
#df.str.replace('Unknown', np.nan)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9836\2307961072.py in ?()
#       1 # Replace "Unknown" values with NaN using numpy library
#       2
#       3 # Your Code is Here
# ----> 4 df.str.replace('Unknown', np.nan)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
# Your Code is Here
df.isnull().sum()
# Out:
# age                          0
# workclass                    0
# fnlwgt                       0
# education                    0
# education-num              802
# marital-status               0
# occupation                   0
# relationship              5064
# race                         0
# sex                          0
# capital-gain                 0
# capital-loss                 0
# hours-per-week               0
# native-country               0
# salary                       0
# marital_status_summary       0
# native_country_summary       0
# education_summary            0
# dtype: int64

# %% [raw]
# Desired Output:
#
# age                          0
# workclass                 1836
# fnlwgt                       0
# occupation                1843
# race                         0
# gender                       0
# capital_gain                 0
# capital_loss                 0
# hours_per_week               0
# salary                       0
# education_summary            0
# marital_status_summary       0
# native_country_summary       0
# dtype: int64

# %%
# Drop missing values in df permanently

# Your Code is Here

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30694 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     30694 non-null  int64
#  1   workclass               30694 non-null  object
#  2   fnlwgt                  30694 non-null  int64
#  3   occupation              30694 non-null  object
#  4   race                    30694 non-null  object
#  5   gender                  30694 non-null  object
#  6   capital_gain            30694 non-null  int64
#  7   capital_loss            30694 non-null  int64
#  8   hours_per_week          30694 non-null  int64
#  9   salary                  30694 non-null  object
#  10  education_summary       30694 non-null  object
#  11  marital_status_summary  30694 non-null  object
#  12  native_country_summary  30694 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 3.3+ MB

# %% [markdown]
# <a id="8"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Handling with Outliers</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## Analyzing all Features  and Detecting Extreme Values

# %% [markdown]
# ### Boxplot and Histplot for all numeric features
#
# **Plot boxplots for each numeric features at the same figure as subplots**

# %%
# Your Code is Here
plt.figure(figsize=(6, 4))
numeric_columns = df.select_dtypes(include=['int64', 'float64'])


sns.boxplot(data=numeric_columns, showmeans=False) 
plt.title("Boxplot for Numeric Features")
plt.xlabel("Values")

plt.show()

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/DKMSBDk/94.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/JKtcs9S/95.png)

# %% [markdown]
# **Plot both boxplots and histograms for each numeric features at the same figure as subplots**

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/fMpP3yR/96.png)

# %% [markdown]
# **Check the statistical values for all numeric features**

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/t3MJHDr/97.png)

# %% [markdown]
# **1. After analyzing all features, we have decided that we can't evaluate extreme values in "fnlwgt, capital_gain, capital_loss" features in the scope of outliers.**
#
# **2. So let's examine "age and hours_per_week" features and detect extreme values which could be outliers by using IQR Rule.**

# %% [markdown]
# ### age

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/SnzH5Nz/98.png)

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (28.0, 47.0, 19.0)

# %%
# Find lower and upper limit using IQR

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (-0.5, 75.5)

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 90    35
# 76    30
# 77    20
# 80    16
# 79    15
# 81    14
# 78    14
# 84     8
# 82     7
# 83     5
# 88     3
# 85     3
# 86     1
# Name: age, dtype: int64

# %%
# Define the observations whose age is greater than upper limit and sort these observations by age in descending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/x2wDgzQ/99.png)

# %% [markdown]
# ### hours_per_week

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/xq53X6w/100.png)

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (40.0, 45.0, 5.0)

# %%
# Find the lower and upper limit using IQR

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (32.5, 52.5)

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 99      80
# 98      11
# 97       2
# 96       5
# 95       2
# 94       1
# 92       1
# 91       3
# 90      28
# 89       2
# 88       2
# 87       1
# 86       2
# 85      13
# 84      41
# 82       1
# 81       3
# 80     124
# 78       8
# 77       6
# 76       3
# 75      63
# 74       1
# 73       2
# 72      68
# 70     284
# 68      12
# 67       4
# 66      17
# 65     242
# 64      14
# 63      10
# 62      18
# 61       2
# 60    1441
# 59       5
# 58      27
# 57      17
# 56      91
# 55     683
# 54      39
# 53      23
# Name: hours_per_week, dtype: int64

# %%
# Define the observations where  hours per week are greater than upper limit and 
# sort these observations by hours per week in descending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/zGCnbjz/101.png)

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 1        8
# 2       15
# 3       24
# 4       28
# 5       39
# 6       40
# 7       20
# 8      103
# 9       17
# 10     223
# 11       9
# 12     143
# 13      19
# 14      28
# 15     350
# 16     182
# 17      27
# 18      64
# 19      14
# 20    1066
# 21      23
# 22      39
# 23      20
# 24     220
# 25     582
# 26      30
# 27      28
# 28      74
# 29       6
# 30    1009
# 31       5
# 32     239
# Name: hours_per_week, dtype: int64

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/swYNtdM/102.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/S7RWpxD/103.png)

# %% [markdown]
# **Result :** As we see, there are number of extreme values in both "age and hours_per_week" features. But how can we know if these extreme values are outliers or not? At this point, **domain knowledge** comes to the fore.
#
# **Domain Knowledge for this dataset:**
# 1. In this dataset, all values are created according to the statements of individuals. So It can be some "data entries errors".
# 2. In addition, we have aimed to create an ML model with some restrictions as getting better performance from the ML model.
# 3. In this respect, our sample space ranges for some features are as follows.
#     - **age : 17 to 80**
#     - **hours_per_week : 7 to 70**
#     - **if somebody's age is more than 60, he/she can't work more than 60 hours in a week**

# %% [markdown]
# ### Dropping rows according to the domain knownledge

# %%
# Create a condition according to your domain knowledge on age stated above and 
# sort the observations meeting this condition by age in ascending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/pJC50ZV/104.png)

# %%
# Find the shape of the dataframe created by the condition defined above for age 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (76, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for age

# Your Code is Here

# %% [raw]
# Desired Output:
#
# Int64Index([  222, 18832, 10545, 11512, 11996, 12975, 14159, 15892, 18277,
#             18413, 18725, 19212,  8973, 19489, 19747, 20610, 22220, 24043,
#             28463, 31030, 32277, 32367, 10210, 15356,  5370,  4070,  1040,
#              6232,  1935,  2303,  5272,  6624,  2891,  5406,  8806,  1168,
#             22895, 21835, 24027, 20463,  8381, 32459, 26731, 27795,  9471,
#              6214, 14711, 11238,  7720, 15662,  7481, 24395, 23459, 19172,
#             16302, 14756,  8431, 20421, 22481, 31855, 13696, 24280,  4834,
#             29594, 28948, 12830,   918, 13295, 24560,  3537, 13928, 19045,
#              6748,  2906, 21501, 19495],
#            dtype='int64')

# %%
# Drop these indices defined above for age

# Your Code is Here

# %%
# Create a condition according to your domain knowledge on hours per week stated above and 
# sort the observations meeting this condition by hours per week in descending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/rMp7C58/105.png)

# %%
# Find the shape of the dataframe created by the condition defined above for hours per week 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (621, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for hours per week

# Your Code is Here

# %% [raw]
# Desired Output:
#
# Int64Index([22216,  5432, 19053, 19141, 19399, 19529, 19731, 19997, 20036,
#             21056,
#             ...
#              6180, 29867,  1036, 11451, 22960, 20909, 25078, 19750,   189,
#             24284],
#            dtype='int64', length=621)

# %%
# Drop these indices defined above for hours per week

# Your Code is Here

# %%
# Create a condition according to your domain knowledge on both age and hours per week stated above 

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Ch8XSdW/106.png)

# %%
# Find the shape of the dataframe created by the condition defined above for both age and hours per week


# Your Code is Here

# %% [raw]
# Desired Output:
#
# (23, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for both age and hours per week

# Your Code is Here

# %% [raw]
# Desired Output:
#
# Int64Index([ 1541,  2154,  2184,  2665,  3101,  5417,  6826,  8066,  9646,
#             12624, 16634, 18367, 19584, 20125, 23399, 23585, 24903, 25910,
#             26625, 27721, 28294, 31342, 32192],
#            dtype='int64')

# %%
# Drop these indices defined above for both age and hours per week

# Your Code is Here

# %%
# What is new shape of dataframe now

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (29974, 13)

# %%
# Reset the indices and take the head of DataFrame now

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5MXPD2b/107.png)

# %% [markdown]
# <a id="9"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## Final Step
# - Convert all features to numeric
# - Take a look at correlation between features by utilizing power of visualizing

# %% [markdown]
# ### Convert all features to numeric

# %% [markdown]
# **Convert target feature (salary) to numeric (0 and 1) by using map function**

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 29969    0
# 29970    1
# 29971    0
# 29972    0
# 29973    1
# Name: salary, Length: 29974, dtype: int64

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 0    22524
# 1     7450
# Name: salary, dtype: int64

# %% [markdown]
# **Convert all features to numeric by using get_dummies function**

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0F1SHRt/108.png)

# %%
# What's the shape of dataframe

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (29974, 13)

# %%
# What's the shape of dataframe created by dummy operation

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (29974, 34)

# %% [markdown]
# ### Take a look at correlation between features by utilizing power of visualizing

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Dgb8RYZ/109.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5XH3X4q/110.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/19RytkS/111.png)

# %%
# Your Code is Here

# %% [markdown]
# ![image.png](https://i.ibb.co/80GcYKr/112.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0MCPc4d/113.png)

# %% [markdown]
# <a id="10"></a>
#
# <p style="background-color:romance; color:plum; font-size:220%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1; font-weight:bold;">The End of the Project</p>
#
# <p style="text-align: center; line-height: 1"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# <p style="background-color:romance; color:plum; font-size:150%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1; font-weight:bold;">WAY TO REINVENT YOURSELF</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
